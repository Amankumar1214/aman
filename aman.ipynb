# %%
import pandas as pd
from collections import defaultdict
from os import getcwd

# %% [markdown]
# #DEFINING PATH TO DATASET

# %%
path_record=f"{getcwd()}/dataStore/heart_failure_clinical_records_dataset.csv"

# %% [markdown]
# #DATA ENGINEERING

# %%
df=pd.read_csv('heart_failure_clinical_records_dataset.csv')
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %% [markdown]
# #CONVERSION OF DATA INTO A SINGLE DICTIONARY

# %%
df_table_columns=df.columns.tolist()
print(f" COLUMNS : {df_table_columns}")
# Out:
#  COLUMNS : ['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes', 'ejection_fraction', 'high_blood_pressure', 'platelets', 'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time', 'DEATH_EVENT']

# %%
#sort the dataset on the basis of deathevent 
df.head(5)
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
#it will return the number of unique values for each variable
df.nunique(axis=0)
# Out:
# age                          47
# anaemia                       2
# creatinine_phosphokinase    208
# diabetes                      2
# ejection_fraction            17
# high_blood_pressure           2
# platelets                   176
# serum_creatinine             40
# serum_sodium                 27
# sex                           2
# smoking                       2
# time                        148
# DEATH_EVENT                   2
# dtype: int64

# %%
print(df.isna().sum())
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
df['DEATH_EVENT'].value_counts()
# Out:
# 0    203
# 1     96
# Name: DEATH_EVENT, dtype: int64

# %%
import matplotlib as plt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corr = df.corr()
plt.subplots(figsize=(15,10))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
sns.heatmap(corr, xticklabels=corr.columns,
            yticklabels=corr.columns, 
            annot=True,
            cmap=sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# <AxesSubplot:>

# %%
subData = df[['age',                         
'anaemia',                     
'creatinine_phosphokinase',  
'diabetes',                   
'ejection_fraction',           
'high_blood_pressure']]
sns.pairplot(subData)

# %%
pos_df = df[df['DEATH_EVENT']==1]
pos_df.describe()
# Out:
#              age    anaemia  creatinine_phosphokinase   diabetes  \
# count  96.000000  96.000000                 96.000000  96.000000
# mean   65.215281   0.479167                670.197917   0.416667
# std    13.214556   0.502188               1316.580640   0.495595
# min    42.000000   0.000000                 23.000000   0.000000
# 25%    55.000000   0.000000                128.750000   0.000000
# 50%    65.000000   0.000000                259.000000   0.000000
# 75%    75.000000   1.000000                582.000000   1.000000
# max    95.000000   1.000000               7861.000000   1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count          96.000000             96.00000      96.000000
# mean           33.468750              0.40625  256381.044792
# std            12.525303              0.49371   98525.682856
# min            14.000000              0.00000   47000.000000
# 25%            25.000000              0.00000  197500.000000
# ...

# %%
pos_df = df[df['DEATH_EVENT']==0]
pos_df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  203.000000  203.000000                203.000000  203.000000
# mean    58.761906    0.408867                540.054187    0.418719
# std     10.637890    0.492840                753.799572    0.494569
# min     40.000000    0.000000                 30.000000    0.000000
# 25%     50.000000    0.000000                109.000000    0.000000
# 50%     60.000000    0.000000                245.000000    0.000000
# 75%     65.000000    1.000000                582.000000    1.000000
# max     90.000000    1.000000               5209.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         203.000000           203.000000     203.000000
# mean           40.266010             0.325123  266657.489901
# std            10.859963             0.469579   97531.202283
# min            17.000000             0.000000   25100.000000
# ...
